# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import time

# %%
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
df_books = pd.read_csv('books.csv').drop('Unnamed: 0', axis=1)
df_ratings = pd.read_csv('ratings.csv').drop('Unnamed: 0', axis=1)
df_ratings_ori = pd.read_csv('BX-Book-Ratings.csv',sep=';',encoding='iso-8859-1',error_bad_lines=False)

# %% [markdown]
# # Creating example users

# %%
alice = {'Name': 'Alice', 'Age': 30.0, 'Country': 'usa', 'Ratings': {'0140324623': 9, '0140434895': 10, '0451526562': 9, '0451521951': 10,  '0451527747': 7, 
                                                                   '0451524934': 10, '0060929871': 10, '0399501487': 8, '0618002219': 7, '0553211404': 8, 
                                                                   '0684801523': 9, '0140430075': 7, '0140430229': 6, '0486282112': 9, '0590203509': 8, 
                                                                   '0486280616': 6}}

# %%
bob = {'Name':'Bob', 'Age': 26.0, 'Country': 'usa', 'Ratings': {'0590353403': 0, '0439064872': 0, '0439136369': 0, '0812511816': 0, '0812517725': 0, 
                                                                '0812513711': 0, '0812513738': 0, '0812575717': 0, '0425080021': 0, '0553580272': 0, 
                                                                '0553580302': 0, '0553580337': 0, '0345339703': 0, '0345339711': 0, '0345339738': 0}}

# %% [markdown]
# + Charlie is one of the users removed during cleaning

# %%
user_c = df_ratings_ori.loc[df_ratings_ori["User-ID"] == 140000]

# %%
charlie = {'Name':'Charlie', 'Age': 40.0, 'Country': 'usa', 'Ratings': {}}

# %%
for i in range(0, len(user_c)):
    if df_books['ISBN'].str.contains(user_c.iloc[i]['ISBN']).any():
        charlie['Ratings'][user_c.iloc[i]['ISBN']] = user_c.iloc[i]['Book-Rating']

# %% [markdown]
# # Showing individual user ratings

# %%
def user_ratings(user):
    df_userrate = pd.DataFrame.from_dict(user["Ratings"], orient='index', columns=['Rating']).sort_values(by=['Rating'], ascending=False)
    df_userrate = df_userrate.rename(index = dict(zip(df_books["ISBN"], df_books["Book-Title"])))
    print("User Name: " + user["Name"])
    print(df_userrate)

# %% [markdown]
# + Alice likes classical literature and frequently rates her books

# %%
user_ratings(alice)
# Out:
# User Name: Alice
#                                                     Rating
# Great Expectations                                      10
# The Count of Monte Cristo                               10
# 1984                                                    10
# Brave New World                                         10
# Anne of Green Gables                                     9
# A Tale of Two Cities                                     9
# The Great Gatsby                                         9
# Frankenstein (Dover Thrift Editions)                     9
# Lord of the Flies                                        8
# Jane Eyre (Bantam Classics)                              8
# Little Women                                             8
# Alice's Adventures in Wonderland and Through th...       7
# The Hobbit: or There and Back Again                      7
# Robinson Crusoe                                          7
# Gulliver's Travels (Penguin Classics)                    6
# Adventures of Huckleberry Finn (Dover Thrift Ed...       6

# %% [markdown]
# + Bob likes fantasy and doesn't bother with ratings

# %%
user_ratings(bob)
# Out:
# User Name: Bob
#                                                     Rating
# Harry Potter and the Sorcerer's Stone (Book 1)           0
# Harry Potter and the Chamber of Secrets (Book 2)         0
# Harry Potter and the Prisoner of Azkaban (Book 3)        0
# The Eye of the World (The Wheel of Time, Book 1)         0
# The Great Hunt (The Wheel of Time, Book 2)               0
# The Dragon Reborn (The Wheel of Time, Book 3)            0
# The Shadow Rising (The Wheel of Time, Book 4)            0
# Ender's Shadow                                           0
# Dune                                                     0
# House Atreides (Dune: House Trilogy, Book 1)             0
# House Harkonnen (Dune: House Trilogy, Book 2)            0
# House Corrino (Dune: House Trilogy, Book 3)              0
# The Fellowship of the Ring (The Lord of the Rin...       0
# The Two Towers (The Lord of the Rings, Part 2)           0
# The Return of the King (The Lord of the Rings, ...       0

# %% [markdown]
# + Charlie appears to be a middle aged housewife with a tendency towards the romance genre

# %%
user_ratings(charlie)
# Out:
# User Name: Charlie
#                                                     Rating
# The No. 1 Ladies' Detective Agency                      10
# Where the Heart Is (Oprah's Book Club (Paperback))      10
# Year of Wonders                                         10
# Blindsighted                                            10
# An Instance of the Fingerpost                           10
# True History of the Kelly Gang                          10
# Atonement : A Novel                                     10
# The Lovely Bones: A Novel                               10
# Grave Secrets (Temperance Brennan Novel (Hardco...      10
# The Last Time They Met : A Novel                        10
# Lasher                                                  10
# Bel Canto: A Novel                                       9
# Four To Score (A Stephanie Plum Novel)                   9
# One for the Money (A Stephanie Plum Novel)               9
# The Subtle Knife (His Dark Materials, Book 2)            9
# Fatal Voyage                                             9
# The Visitant (The Anasazi Mysteries, Book 1)             9
# The Pilot's Wife : A Novel                               8
# The Constant Gardener                                    8
# A Heartbreaking Work of Staggering Genius                8
# Open Season                                              8
# Lucky Man: A Memoir                                      8
# Master and Commander (Aubrey-Maturin (Paperback))        8
# Kindred (Black Women Writers Series)                     8
# Track of the Cat (Anna Pigeon Mysteries (Paperb...       8
# Left Behind: A Novel of the Earth's Last Days (...       8
# Pope Joan (Ballantine Reader's Circle)                   8
# The Chamber                                              8
# Big Stone Gap: A Novel (Ballantine Reader's Cir...       8
# Drowning Ruth (Oprah's Book Club)                        8
# ...                                                    ...
# Portrait in Death                                        0
# Stupid White Men ...and Other Sorry Excuses for...       0
# Flashback                                                0
# Harry Potter and the Order of the Phoenix (Book 5)       0
# Hannibal                                                 0
# The Brethren                                             0
# Tell No One                                              0
# Gone for Good                                            0
# Along Came a Spider (Alex Cross Novels)                  0
# Pleading Guilty                                          0
# The Day After Tomorrow                                   0
# Thyme of Death: A China Bayles Mystery (West Co...       0
# Lightning                                                0
# The Blue Flower                                          0
# Can You Keep a Secret?                                   0
# A Superior Death                                         0
# Firestorm (Anna Pigeon Mysteries (Paperback))            0
# Endangered Species (Anna Pigeon Mysteries (Pape...       0
# Blind Descent: : An Anna Pigeon Mystery (Anna P...       0
# Liberty Falling (Anna Pigeon Mysteries (Paperba...       0
# Lamb : The Gospel According to Biff, Christ's C...       0
# Tuesdays with Morrie: An Old Man, a Young Man, ...       0
# Morality Play                                            0
# English Passengers                                       0
# Oryx and Crake                                           0
# Atonement: A Novel                                       0
# The Curious Incident of the Dog in the Night-Ti...       0
# The Map of Love                                          0
# Balzac and the Little Chinese Seamstress : A Novel       0
# Comme un roman                                           0
#
# [176 rows x 1 columns]

# %% [markdown]
# # Recommendation function

# %% [markdown]
# + Function takes the method (defined below), user and number of recommendations as arguments

# %%
def recommend(method, user, rec_no):
    rating_dict = user["Ratings"]
    rec_list = method(rating_dict)
    rec_list = rec_list.drop(list(user['Ratings'].keys())).sort_values(ascending=False).head(rec_no)
    return df_books.loc[df_books["ISBN"].isin(rec_list.index)]

# %% [markdown]
# # Implicit correlation

# %%
irate_corr = pd.DataFrame.from_csv("irate_corr.csv")

# %%
def implicit(rating_dict):
    array_sum = irate_corr[list(rating_dict.keys())[0]].copy()
    if len(list(rating_dict.keys())) == 1:
        pass
    else:
        for i in range(1, len(list(rating_dict.keys()))):
            array_sum += irate_corr[list(rating_dict.keys())[i]]
    return array_sum

# %%
recommend(implicit, alice, 20)
# Out:
#             ISBN                                         Book-Title  \
# 7     0446310786                              To Kill a Mockingbird
# 16    0440225701                                  The Street Lawyer
# 99    0451526341                                        Animal Farm
# 134   0316666343                          The Lovely Bones: A Novel
# 174   0312278586                         The Nanny Diaries: A Novel
# 323   0060914653                  The Unbearable Lightness of Being
# 344   0553273604                                Of Love and Shadows
# 404   0553296981              Anne Frank: The Diary of a Young Girl
# 432   0345361792                            A Prayer for Owen Meany
# 439   1400034779  The No. 1 Ladies' Detective Agency (Today Show...
# 448   080410753X                             The Kitchen God's Wife
# 871   0380002930                                     Watership Down
# 893   0767907817                                 Bookends : A Novel
# 1036  0316096199                                   Lucky : A Memoir
# 1401  0446670251                                The Virgin Suicides
# 2339  0316769495                                   Franny and Zooey
# 2883  014100018X                                           Chocolat
# 3826  0440445450                             How to Eat Fried Worms
# 3851  0140430164                  Mansfield Park (Penguin Classics)
# 4291  038000741X                                 Monkey Wrench Gang
#
#                  Book-Author  Year-Of-Publication               Publisher
# 7                 Harper Lee                 1988  Little Brown & Company
# 16              JOHN GRISHAM                 1999                    Dell
# 99             George Orwell                 2004                  Signet
# 134             Alice Sebold                 2002           Little, Brown
# 174          Emma McLaughlin                 2002      St. Martin's Press
# 323            Milan Kundera                 1988           Harpercollins
# 344           Isabel Allende                 1988            Bantam Books
# 404               ANNE FRANK                 1993                  Bantam
# 432              John Irving                 1990        Ballantine Books
# 439   Alexander McCall Smith                 2003                  Anchor
# 448                  Amy Tan                 1992               Ivy Books
# 871            Richard Adams                 1976                    Avon
# 893               Jane Green                 2003                Broadway
# 1036            Alice Sebold                 2002          Back Bay Books
# 1401       Jeffrey Eugenides                 1994            Warner Books
# 2339           J.D. Salinger                 1991           Little, Brown
# 2883           Joanne Harris                 2000           Penguin Books
# 3826         THOMAS ROCKWELL                 1953                Yearling
# 3851             Jane Austen                 1988             Penguin USA
# 4291            Edward Abbey                 1976                    Avon

# %% [markdown]
# # Content based correlation

# %%
desc_coscorr_2 = pd.DataFrame.from_csv("desc_coscorr_2.csv")

# %%
def content(rating_dict):
    array_sum = desc_coscorr_2[list(rating_dict.keys())[0]].copy()
    if len(list(rating_dict.keys())) == 1:
        pass
    else:
        for i in range(1, len(list(rating_dict.keys()))):
            array_sum += desc_coscorr_2[list(rating_dict.keys())[i]]
    return array_sum

# %%
recommend(content, bob, 20)
# Out:
#             ISBN                                         Book-Title  \
# 512   0812565959  Shadow of the Hegemon (Ender Wiggins Saga (Pap...
# 633   0345416880                                        Enchantment
# 655   059035342X  Harry Potter and the Sorcerer's Stone (Harry P...
# 669   0812550706      Ender's Game (Ender Wiggins Saga (Paperback))
# 673   0441294677      God Emperor of Dune (Dune Chronicles, Book 4)
# 674   0441104029         Children of Dune (Dune Chronicles, Book 3)
# 683   0812513754          Lord of Chaos (The Wheel of Time, Book 6)
# 684   0812550307    The Fires of Heaven (The Wheel of Time, Book 5)
# 911   0345339681  The Hobbit : The Enchanting Prelude to The Lor...
# 1345  0439139597       Harry Potter and the Goblet of Fire (Book 4)
# 1361  043935806X  Harry Potter and the Order of the Phoenix (Boo...
# 2301  0812508645  Pastwatch: The Redemption of Christopher Columbus
# 2427  081257558X         Winter's Heart (The Wheel of Time, Book 9)
# 2621  0812550293    The Path of Daggers (The Wheel of Time, Book 8)
# 2854  0812509250          Xenocide (Ender Wiggins Saga (Paperback))
# 2935  0765341174       Sarah (Card, Orson Scott. Women of Genesis.)
# 4170  0061091316                                          Lost Boys
# 4359  0812522397  Children of the Mind (Ender Wiggins Saga (Pape...
# 4406  0812550285      A Crown of Swords (The Wheel of Time, Book 7)
# 4504  0439425220  Harry Potter and the Chamber of Secrets Postca...
#
#            Book-Author  Year-Of-Publication               Publisher
# 512   Orson Scott Card                 2001               Tor Books
# 633   Orson Scott Card                 2000           Del Rey Books
# 655      J. K. Rowling                 1999  Arthur A. Levine Books
# 669   Orson Scott Card                 1994               Tor Books
# 673      Frank Herbert                 1991             ACE Charter
# 674      Frank Herbert                 1991               Ace Books
# 683      Robert Jordan                 1995             Tor Fantasy
# 684      Robert Jordan                 1994             Tor Fantasy
# 911     J.R.R. TOLKIEN                 1986                 Del Rey
# 1345     J. K. Rowling                 2000              Scholastic
# 1361     J. K. Rowling                 2003              Scholastic
# 2301  Orson Scott Card                 1997               Tor Books
# 2427     Robert Jordan                 2002               Tor Books
# 2621     Robert Jordan                 1999             Tor Fantasy
# 2854  Orson Scott Card                 1992               Tor Books
# 2935  Orson Scott Card                 2001                   Forge
# 4170  Orson Scott Card                 1993             HarperTorch
# 4359  Orson Scott Card                 1997               Tor Books
# 4406     Robert Jordan                 1997             Tor Fantasy
# 4504     J. K. Rowling                 2002              Scholastic

# %% [markdown]
# # Matrix factorization

# %% [markdown]
# + This is nearly the same code as before but with the following modifications:
#     + Input matrix is now only a single row for the new user
#     + Item matrix Q is loaded from previous results and is fixed. We only optimize for the single user
#     + Code is set to run for a fixed time (set at 0.5s here) to ensure recommendations can be updated in real time

# %%
ratings_pivot = df_ratings.pivot(index='User-ID', columns='ISBN')["Book-Rating"]

# %%
def matrix(rating_dict):
    blank_matrix = pd.DataFrame(np.NaN, index=[0], columns=ratings_pivot.columns)
    class MF():

        def __init__(self, R, K, alpha, beta, runtime):
            """
            Perform matrix factorization to predict empty
            entries in a matrix.

            Arguments
            - R (ndarray)   : user-item rating matrix
            - K (int)       : number of latent dimensions
            - alpha (float) : learning rate
            - beta (float)  : regularization parameter
            """

            self.R = R
            self.num_users, self.num_items = R.shape
            self.K = K
            self.alpha = alpha
            self.beta = beta
            self.runtime = runtime

        def train(self):
            # Initialize user and item latent feature matrice
            self.P = np.random.normal(scale=1./self.K, size=(self.num_users, self.K))
            self.Q = np.load('mf_weights.npy')

            # Initialize the biases
            self.b_u = np.zeros(self.num_users)
            self.b_i = np.zeros(self.num_items)
            self.b = np.mean(self.R[np.where(self.R != 0)])

            # Create a list of training samples
            self.samples = [
                (i, j, self.R[i, j])
                for i in range(self.num_users)
                for j in range(self.num_items)
                if self.R[i, j] > 0
            ]

            # Perform stochastic gradient descent for number of iterations
            training_process = []
            ts = time.time()
            iteration = 1
            while True:
                np.random.shuffle(self.samples)
                self.sgd()
                mse = self.mse()
                training_process.append((i, mse))

    #             print("Iteration: %d ; error = %.4f ; time taken = %.4f seconds" % (iteration, mse, time.time() - ts))
                iteration += 1

                if (time.time() - ts) > self.runtime:
    #                 print("Stopping training")
                    break
            return training_process

        def mse(self):
            """
            A function to compute the total mean square error
            """
            xs, ys = self.R.nonzero()
            predicted = self.full_matrix()
            error = 0
            for x, y in zip(xs, ys):
                error += pow(self.R[x, y] - predicted[x, y], 2)
            return np.sqrt(error)

        def sgd(self):
            """
            Perform stochastic gradient descent
            """
            for i, j, r in self.samples:
                # Computer prediction and error
                prediction = self.get_rating(i, j)
                e = (r - prediction)

                # Update biases
                self.b_u[i] += self.alpha * (e - self.beta * self.b_u[i])
                self.b_i[j] += self.alpha * (e - self.beta * self.b_i[j])

                # Update user and item latent feature matrices
                self.P[i, :] += self.alpha * (e * self.Q[j, :] - self.beta * self.P[i,:])

        def get_rating(self, i, j):
            """
            Get the predicted rating of user i and item j
            """
            prediction = self.b + self.b_u[i] + self.b_i[j] + self.P[i, :].dot(self.Q[j, :].T)
            return prediction

        def full_matrix(self):
            """
            Computer the full matrix using the resultant biases, P and Q
            """
            return mf.b + mf.b_u[:,np.newaxis] + mf.b_i[np.newaxis:,] + mf.P.dot(mf.Q.T)
        
    for i in range(0, len(list(rating_dict.values()))):
        blank_matrix[list(rating_dict.keys())[i]].iloc[0] = list(rating_dict.values())[i]

    blank_matrix = blank_matrix.fillna(0)
    blank_matrix = blank_matrix.astype('int32')
    R = blank_matrix.values

    mf = MF(R, K=32, alpha=0.01, beta=0.001, runtime=0.5)
    mf.train()
    full_matrix = mf.full_matrix()
    return pd.DataFrame(np.transpose(mf.full_matrix()), index=ratings_pivot.columns)[0]

# %%
recommend(matrix, charlie, 20)
# Out:
#             ISBN                                         Book-Title  \
# 19    042511774X                                  Breathing Lessons
# 312   0312282990          The Amazing Adventures of Kavalier & Clay
# 349   0671003755  She's Come Undone (Oprah's Book Club (Paperback))
# 443   037570504X                               Breath, Eyes, Memory
# 592   0440235464                                         Lost Girls
# 663   0671708635            Seven Habits Of Highly Effective People
# 766   0671695304  FOREVER : A Novel of Good and Evil, Love and Hope
# 792   051513287X       Face the Fire (Three Sisters Island Trilogy)
# 962   0425118703                                           Midnight
# 1160  0380017601                                         Love Story
# 1275  074322535X                 Gap Creek: The Story of a Marriage
# 1293  014028009X                              Bridget Jones's Diary
# 1427  0446600253                                   Bless Me, Ultima
# 2061  006098824X                                    Getting Over It
# 2088  0670825379                                 The Satanic Verses
# 2360  0425092917                             The Accidental Tourist
# 2990  0452282195                                     The Bluest Eye
# 3811  0140481346                                Death of A Salesman
# 3954  0446608602                                  Personal Injuries
# 4529  0525943749     Son of Rosemary: The Sequel to Rosemary's Baby
#
#            Book-Author  Year-Of-Publication                 Publisher
# 19          Anne Tyler                 1994  Berkley Publishing Group
# 312     Michael Chabon                 2001                   Picador
# 349         Wally Lamb                 1996   Washington Square Press
# 443   Edwidge Danticat                 1998         Vintage Books USA
# 592       Andrew Pyper                 2001   Dell Publishing Company
# 663   Stephen R. Covey                 1990                Free Press
# 766         Judy Blume                 1989                    Pocket
# 792       Nora Roberts                 2002                Jove Books
# 962     Dean R. Koontz                 1995  Berkley Publishing Group
# 1160       Erich Segal                 2002               HarperTorch
# 1275     Robert Morgan                 2001                Touchstone
# 1293    Helen Fielding                 1999             Penguin Books
# 1427     Rudolfo Anaya                 1994              Warner Books
# 2061       Anna Maxted                 2001               Regan Books
# 2088    Salman Rushdie                 1989              Viking Books
# 2360        Anne Tyler                 1994  Berkley Publishing Group
# 2990     Toni Morrison                 2000               Plume Books
# 3811     Arthur Miller                 1998       Penguin USA (Paper)
# 3954       Scott Turow                 2000             Warner Vision
# 4529         Ira Levin                 1997               Penguin USA

# %% [markdown]
# # Hybrid systems

# %% [markdown]
# ## Weighted
# + Methods are given different weights
# + Here implicit correlation and content based are both given 50% after scaling

# %%
from sklearn import preprocessing

def weighted(rating_dict):
    arr_implicit = (implicit(rating_dict)-implicit(rating_dict).min())/(implicit(rating_dict).max()-implicit(rating_dict).min())
    arr_content = (content(rating_dict)-content(rating_dict).min())/(content(rating_dict).max()-content(rating_dict).min())
    return arr_implicit + arr_content

# %%
recommend(weighted, alice, 20)
# Out:
#             ISBN                                         Book-Title  \
# 7     0446310786                              To Kill a Mockingbird
# 99    0451526341                                        Animal Farm
# 134   0316666343                          The Lovely Bones: A Novel
# 174   0312278586                         The Nanny Diaries: A Novel
# 318   0140620125       Wuthering Heights (Penguin Popular Classics)
# 418   0446606812                                Message in a Bottle
# 432   0345361792                            A Prayer for Owen Meany
# 536   0618126988                                   The Silmarillion
# 871   0380002930                                     Watership Down
# 893   0767907817                                 Bookends : A Novel
# 1550  068416325X                The GREAT GATSBY (Scribner Classic)
# 1682  1566840287          The Christmas Box (Christmas Box Trilogy)
# 2365  0020199600                             GREAT GATSBY (REISSUE)
# 2594  1853260231                 Frankenstein (Wordsworth Classics)
# 2679  0553212478                  Frankenstein (Changing Our World)
# 2883  014100018X                                           Chocolat
# 3217  0553211765                Tale of Two Cities (Bantam Classic)
# 3752  0618129111  The Return of the King (The Lord of the Rings,...
# 4275  0140390464  The Adventures of Huckleberry Finn (Penguin Cl...
# 4301  1853260738                                      Moll Flanders
#
#                       Book-Author  Year-Of-Publication  \
# 7                      Harper Lee                 1988
# 99                  George Orwell                 2004
# 134                  Alice Sebold                 2002
# 174               Emma McLaughlin                 2002
# 318                  Emily Bronte                 1994
# 418               Nicholas Sparks                 1999
# 432                   John Irving                 1990
# 536                J.R.R. Tolkien                 2001
# 871                 Richard Adams                 1976
# 893                    Jane Green                 2003
# 1550          F. Scott Fitzgerald                 1979
# 1682           Richard Paul Evans                 1993
# 2365          F. Scott Fitzgerald                 1988
# 2594  Mary Wollstonecraft Shelley                 1997
# 2679  Mary Wollstonecraft Shelley                 1984
# 2883                Joanne Harris                 2000
# 3217              Charles Dickens                 1989
# 3752             J. R. R. Tolkien                 2001
# 4275                   Mark Twain                 1986
# 4301                 Daniel Defoe                 1999
#
#                                 Publisher
# 7                  Little Brown & Company
# 99                                 Signet
# 134                         Little, Brown
# 174                    St. Martin's Press
# 318                     Penguin Books Ltd
# 418                         Warner Vision
# 432                      Ballantine Books
# 536                      Houghton Mifflin
# 871                                  Avon
# 893                              Broadway
# 1550               Scribner Paper Fiction
# 1682                       Pubs Wholesale
# 2365               Scribner Paper Fiction
# 2594  NTC/Contemporary Publishing Company
# 2679                               Bantam
# 2883                        Penguin Books
# 3217                               Bantam
# 3752             Houghton Mifflin Company
# 4275                        Penguin Books
# 4301  NTC/Contemporary Publishing Company

# %% [markdown]
# ## Switching
# + A specific method is chosen based on set criteria
# + Here the method with highest standard deviation is used

# %%
from sklearn import preprocessing

def switching(rating_dict):
    arr_implicit = (implicit(rating_dict)-implicit(rating_dict).min())/(implicit(rating_dict).max()-implicit(rating_dict).min())
    arr_content = (content(rating_dict)-content(rating_dict).min())/(content(rating_dict).max()-content(rating_dict).min())
    arr_matrix = (matrix(rating_dict)-matrix(rating_dict).min())/(matrix(rating_dict).max()-matrix(rating_dict).min())
    val, idx = max((val, idx) for (idx, val) in enumerate([arr_implicit.std() , arr_content.std(), arr_matrix.std()]))
    
    return [implicit, content, matrix][idx](rating_dict)

# %%
recommend(switching, bob, 20)
# Out:
#             ISBN                                         Book-Title  \
# 512   0812565959  Shadow of the Hegemon (Ender Wiggins Saga (Pap...
# 633   0345416880                                        Enchantment
# 655   059035342X  Harry Potter and the Sorcerer's Stone (Harry P...
# 669   0812550706      Ender's Game (Ender Wiggins Saga (Paperback))
# 673   0441294677      God Emperor of Dune (Dune Chronicles, Book 4)
# 674   0441104029         Children of Dune (Dune Chronicles, Book 3)
# 683   0812513754          Lord of Chaos (The Wheel of Time, Book 6)
# 684   0812550307    The Fires of Heaven (The Wheel of Time, Book 5)
# 911   0345339681  The Hobbit : The Enchanting Prelude to The Lor...
# 1345  0439139597       Harry Potter and the Goblet of Fire (Book 4)
# 1361  043935806X  Harry Potter and the Order of the Phoenix (Boo...
# 2301  0812508645  Pastwatch: The Redemption of Christopher Columbus
# 2427  081257558X         Winter's Heart (The Wheel of Time, Book 9)
# 2621  0812550293    The Path of Daggers (The Wheel of Time, Book 8)
# 2854  0812509250          Xenocide (Ender Wiggins Saga (Paperback))
# 2935  0765341174       Sarah (Card, Orson Scott. Women of Genesis.)
# 4170  0061091316                                          Lost Boys
# 4359  0812522397  Children of the Mind (Ender Wiggins Saga (Pape...
# 4406  0812550285      A Crown of Swords (The Wheel of Time, Book 7)
# 4504  0439425220  Harry Potter and the Chamber of Secrets Postca...
#
#            Book-Author  Year-Of-Publication               Publisher
# 512   Orson Scott Card                 2001               Tor Books
# 633   Orson Scott Card                 2000           Del Rey Books
# 655      J. K. Rowling                 1999  Arthur A. Levine Books
# 669   Orson Scott Card                 1994               Tor Books
# 673      Frank Herbert                 1991             ACE Charter
# 674      Frank Herbert                 1991               Ace Books
# 683      Robert Jordan                 1995             Tor Fantasy
# 684      Robert Jordan                 1994             Tor Fantasy
# 911     J.R.R. TOLKIEN                 1986                 Del Rey
# 1345     J. K. Rowling                 2000              Scholastic
# 1361     J. K. Rowling                 2003              Scholastic
# 2301  Orson Scott Card                 1997               Tor Books
# 2427     Robert Jordan                 2002               Tor Books
# 2621     Robert Jordan                 1999             Tor Fantasy
# 2854  Orson Scott Card                 1992               Tor Books
# 2935  Orson Scott Card                 2001                   Forge
# 4170  Orson Scott Card                 1993             HarperTorch
# 4359  Orson Scott Card                 1997               Tor Books
# 4406     Robert Jordan                 1997             Tor Fantasy
# 4504     J. K. Rowling                 2002              Scholastic

# %% [markdown]
# ## Mixed
# + Results from different methods are mixed together
# + Here the recommendations from implicit and matrix are laced in a 1-1 ratio

# %%
def mixed(rating_dict):
    arr_implicit = implicit(rating_dict).sort_values()
    arr_matrix = matrix(rating_dict).sort_values()
    for i in range(0, len(arr_implicit)):
        arr_implicit.iloc[i] = i
        arr_matrix.iloc[i] = i
    return pd.concat([arr_implicit, arr_matrix])

# %%
recommend(mixed, charlie, 20)
# Out:
#             ISBN                                         Book-Title  \
# 19    042511774X                                  Breathing Lessons
# 312   0312282990          The Amazing Adventures of Kavalier & Clay
# 349   0671003755  She's Come Undone (Oprah's Book Club (Paperback))
# 443   037570504X                               Breath, Eyes, Memory
# 592   0440235464                                         Lost Girls
# 663   0671708635            Seven Habits Of Highly Effective People
# 766   0671695304  FOREVER : A Novel of Good and Evil, Love and Hope
# 792   051513287X       Face the Fire (Three Sisters Island Trilogy)
# 962   0425118703                                           Midnight
# 1160  0380017601                                         Love Story
# 1275  074322535X                 Gap Creek: The Story of a Marriage
# 1293  014028009X                              Bridget Jones's Diary
# 1427  0446600253                                   Bless Me, Ultima
# 2061  006098824X                                    Getting Over It
# 2088  0670825379                                 The Satanic Verses
# 2252  0060958014                              Coastliners : A Novel
# 2360  0425092917                             The Accidental Tourist
# 2990  0452282195                                     The Bluest Eye
# 3811  0140481346                                Death of A Salesman
# 4529  0525943749     Son of Rosemary: The Sequel to Rosemary's Baby
#
#            Book-Author  Year-Of-Publication                 Publisher
# 19          Anne Tyler                 1994  Berkley Publishing Group
# 312     Michael Chabon                 2001                   Picador
# 349         Wally Lamb                 1996   Washington Square Press
# 443   Edwidge Danticat                 1998         Vintage Books USA
# 592       Andrew Pyper                 2001   Dell Publishing Company
# 663   Stephen R. Covey                 1990                Free Press
# 766         Judy Blume                 1989                    Pocket
# 792       Nora Roberts                 2002                Jove Books
# 962     Dean R. Koontz                 1995  Berkley Publishing Group
# 1160       Erich Segal                 2002               HarperTorch
# 1275     Robert Morgan                 2001                Touchstone
# 1293    Helen Fielding                 1999             Penguin Books
# 1427     Rudolfo Anaya                 1994              Warner Books
# 2061       Anna Maxted                 2001               Regan Books
# 2088    Salman Rushdie                 1989              Viking Books
# 2252     Joanne Harris                 2003                 Perennial
# 2360        Anne Tyler                 1994  Berkley Publishing Group
# 2990     Toni Morrison                 2000               Plume Books
# 3811     Arthur Miller                 1998       Penguin USA (Paper)
# 4529         Ira Levin                 1997               Penguin USA

# %% [markdown]
# # Other hybrid methods
#
# ## Feature Combination
# + Features derived from different knowledge sources are combined together and given to a single recommendation algorithm
# + This is similar to what was done during the content-based approach (TF-IDF scores were merged with dummies for Author and Publisher before calculating cosine similarity)
#
# ## Feature Augmentation
# + One recommendation technique is used to compute a feature or set of features, which is then part of the input to the next technique
#
# ## Cascade
# + Recommenders are given strict priority, with the lower priority ones breaking ties in the scoring of the higher ones
# + The individual methods used here all produce a continuous rating, so this is not applicable
#
# ## Meta-level
# + One recommendation technique is applied and produces some sort of model, which is then the input used by the next technique
